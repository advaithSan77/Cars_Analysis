# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('USA_cars_datasets.csv')

# %%
df
# Out:
#       Unnamed: 0  price      brand  ...       state  country      condition
# 0              0   6300     toyota  ...  new jersey      usa   10 days left
# 1              1   2899       ford  ...   tennessee      usa    6 days left
# 2              2   5350      dodge  ...     georgia      usa    2 days left
# 3              3  25000       ford  ...    virginia      usa  22 hours left
# 4              4  27700  chevrolet  ...     florida      usa  22 hours left
# ...          ...    ...        ...  ...         ...      ...            ...
# 2494        2494   7800     nissan  ...  california      usa    1 days left
# 2495        2495   9200     nissan  ...     florida      usa  21 hours left
# 2496        2496   9200     nissan  ...     florida      usa  21 hours left
# 2497        2497   9200     nissan  ...     florida      usa    2 days left
# 2498        2498   9200     nissan  ...     florida      usa  21 hours left
#
# [2499 rows x 13 columns]

# %%
del df['Unnamed: 0']
del df['condition']
del df['lot']

# %%
df.head(10)
# Out:
#    price      brand    model  ...                  vin       state  country
# 0   6300     toyota  cruiser  ...    jtezu11f88k007763  new jersey      usa
# 1   2899       ford       se  ...    2fmdk3gc4bbb02217   tennessee      usa
# 2   5350      dodge      mpv  ...    3c4pdcgg5jt346413     georgia      usa
# 3  25000       ford     door  ...    1ftfw1et4efc23745    virginia      usa
# 4  27700  chevrolet     1500  ...    3gcpcrec2jg473991     florida      usa
# 5   5700      dodge      mpv  ...    2c4rdgeg9jr237989       texas      usa
# 6   7300  chevrolet       pk  ...    1gcsksea1az121133     georgia      usa
# 7  13350        gmc     door  ...    1gks2gkc3hr326762  california      usa
# 8  14600  chevrolet   malibu  ...    1g1zd5st5jf191860     florida      usa
# 9   5250       ford      mpv  ...    2fmpk3j92hbc12542       texas      usa
#
# [10 rows x 10 columns]

# %%
df.isna().sum()
# Out:
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# state           0
# country         0
# dtype: int64

# %% [markdown]
# #No. of cars purchased of each brand

# %%
brand_nos = pd.DataFrame(df.groupby('brand', as_index=False, sort=True)['vin'].count())
brand_nos.sort_values(by=['vin'], ascending=False, inplace=True)
brand_nos.rename(columns={'vin':'No of cars'}, inplace=True)
brand_nos
# Out:
#               brand  No of cars
# 8              ford        1235
# 7             dodge         432
# 24           nissan         312
# 5         chevrolet         297
# 9               gmc          42
# 16             jeep          30
# 6          chrysler          18
# 2               bmw          17
# 13          hyundai          15
# 3             buick          13
# 17              kia          13
# 12            honda          12
# 14         infiniti          12
# 23    mercedes-benz          10
# 4          cadillac          10
# 11        heartland           5
# 1              audi           4
# 25        peterbilt           4
# 18             land           4
# 0             acura           3
# 20          lincoln           2
# 22            mazda           2
# 19            lexus           2
# 21         maserati           1
# 15           jaguar           1
# 10  harley-davidson           1
# 26              ram           1
# 27           toyota           1

# %%
graph = plt.figure(figsize=(25, 10))
plt.bar(brand_nos['brand'], brand_nos['No of cars'], width=0.5)
plt.xlabel('Brand')
plt.ylabel('Number of cars')
plt.title('No. of cars purchased of each brand')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #No. of cars purchased each year

# %%
y_nos = pd.DataFrame(df.groupby(['year'], as_index=False, sort=True)['vin'].count())
#y_nos.sort_values(by='vin', ascending=False, inplace=True)
y_nos.rename(columns={'vin':'No of cars'}, inplace=True)
y_nos
# Out:
#     year  No of cars
# 0   1973           1
# 1   1984           1
# 2   1993           1
# 3   1994           2
# 4   1995           1
# 5   1996           2
# 6   1997           2
# 7   1998           4
# 8   1999           1
# 9   2000           4
# 10  2001           5
# 11  2002           2
# 12  2003           9
# 13  2004           6
# 14  2005           6
# 15  2006           8
# 16  2007           6
# 17  2008          18
# 18  2009          11
# 19  2010          13
# 20  2011          23
# 21  2012          72
# 22  2013          86
# 23  2014         104
# 24  2015         196
# 25  2016         203
# 26  2017         377
# 27  2018         395
# 28  2019         892
# 29  2020          48

# %%
graph = plt.figure(figsize=(25, 10))
plt.plot(y_nos['year'], y_nos['No of cars'], color='black')
plt.xlabel('Year')
plt.ylabel('Number of cars')
plt.title('No. of cars purchased each year')
plt.xticks()
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #No. of cars of each color

# %%
brand_y_nos = pd.DataFrame(df.groupby(['color'], as_index=False, sort=True)['vin'].count())
brand_y_nos.sort_values(by='vin', ascending=False, inplace=True)
brand_y_nos.rename(columns={'vin':'No of cars'}, inplace=True)
brand_y_nos.head(20)
# Out:
#                      color  No of cars
# 46                   white         707
# 2                    black         516
# 15                    gray         395
# 39                  silver         300
# 34                     red         192
# 4                     blue         151
# 27                no_color          61
# 16                   green          24
# 29                  orange          20
# 14                    gold          19
# 9                 charcoal          18
# 6                    brown          15
# 48                  yellow           9
# 24       magnetic metallic           6
# 0                    beige           5
# 38            shadow black           5
# 10                  color:           5
# 30            oxford white           4
# 19   ingot silver metallic           4
# 43  triple yellow tri-coat           3

# %%
graph = plt.figure(figsize=(25, 10))
plt.bar(brand_y_nos['color'], brand_y_nos['vin'], color='blue', width=0.6)
plt.xlabel('Color')
plt.ylabel('Number of cars')
plt.title('No. of cars of each color')
plt.xticks(rotation=80)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #No. of cars of each model

# %%
mod_nos = pd.DataFrame(df.groupby(['model'], as_index=False, sort=True)['vin'].count())
mod_nos.sort_values(by='vin', ascending=False, inplace=True)
mod_nos.rename(columns={'vin':'No of cars'}, inplace=True)
mod_nos.head(20)
# Out:
#           model  No of cars
# 32         door         651
# 50        f-150         219
# 33        doors         148
# 12      caravan         102
# 75          mpv          87
# 58       fusion          65
# 36      durango          64
# 65      journey          61
# 91        rogue          54
# 117         van          46
# 14   challenger          44
# 15      charger          42
# 112     transit          41
# 72          max          41
# 101       sport          40
# 46       escape          39
# 49     explorer          39
# 0          1500          39
# 103         srw          38
# 120       versa          34

# %%
graph = plt.figure(figsize=(28, 10))
plt.bar(mod_nos['model'], mod_nos['No of cars'], color='red', width=0.6)
plt.xlabel('Model')
plt.ylabel('Number of cars')
plt.title('No. of cars of each model')
plt.xticks(rotation=80)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #Maximum car price each year

# %%
year_max = pd.DataFrame(df.groupby(['year'], as_index=False, sort=True)['price'].max())
year_max
# Out:
#     year  price
# 0   1973  29800
# 1   1984     25
# 2   1993      0
# 3   1994     25
# 4   1995      0
# 5   1996      0
# 6   1997      0
# 7   1998     25
# 8   1999     25
# 9   2000    175
# 10  2001   5000
# 11  2002   1400
# 12  2003  13000
# 13  2004   5100
# 14  2005   8600
# 15  2006  14500
# 16  2007   2320
# 17  2008  26500
# 18  2009  10400
# 19  2010   7300
# 20  2011  31200
# 21  2012  29000
# 22  2013  54000
# 23  2014  33800
# 24  2015  46000
# 25  2016  63200
# 26  2017  84900
# 27  2018  63000
# 28  2019  74000
# 29  2020  61200

# %%
graph = plt.figure(figsize=(15, 8))
plt.plot(year_max['year'], year_max['price'], color='black')
plt.xlabel('Year')
plt.ylabel('Maximum car price')
plt.title('Maximum car price each year')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #Average car price each year

# %%
year_mean = pd.DataFrame(df.groupby(['year'], as_index=False, sort=True)['price'].mean())
year_mean
# Out:
#     year         price
# 0   1973  29800.000000
# 1   1984     25.000000
# 2   1993      0.000000
# 3   1994     12.500000
# 4   1995      0.000000
# 5   1996      0.000000
# 6   1997      0.000000
# 7   1998      6.250000
# 8   1999     25.000000
# 9   2000     43.750000
# 10  2001   1485.000000
# 11  2002    700.000000
# 12  2003   2547.222222
# 13  2004   1362.500000
# 14  2005   2387.500000
# 15  2006   3005.625000
# 16  2007    648.333333
# 17  2008   3750.277778
# 18  2009   2041.363636
# 19  2010   2167.307692
# 20  2011   8737.565217
# 21  2012   7657.333333
# 22  2013   8764.244186
# 23  2014  11817.355769
# 24  2015  15563.168367
# 25  2016  18280.911330
# 26  2017  18596.440318
# 27  2018  19058.339241
# 28  2019  24025.404709
# 29  2020  25083.854167

# %%
graph = plt.figure(figsize=(15, 8))
plt.plot(year_mean['year'], year_mean['price'], color='black')
plt.xlabel('Year')
plt.ylabel('Average car price')
plt.title('Average car price each year')
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
df[df['year'] == 1973]
# Out:
#     Unnamed: 0  price      brand  ...         state  country      condition
# 32          32  29800  chevrolet  ...  pennsylvania      usa  22 hours left
#
# [1 rows x 13 columns]

# %% [markdown]
# #No of cars in each state

# %%
state_nos = pd.DataFrame(df.groupby('state', as_index=False, sort=True)['vin'].count())
state_nos.sort_values(by=['vin'], ascending=False, inplace=True)
state_nos.rename(columns={'vin':'No of cars'}, inplace=True)
state_nos
# Out:
#              state  No of cars
# 32    pennsylvania         299
# 6          florida         246
# 36           texas         214
# 3       california         190
# 16        michigan         169
# 27  north carolina         146
# 17       minnesota         119
# 9         illinois         113
# 42       wisconsin          94
# 39        virginia          90
# 24      new jersey          87
# 22          nevada          85
# 29        oklahoma          71
# 34  south carolina          64
# 26        new york          58
# 7          georgia          51
# 19        missouri          46
# 1          arizona          33
# 28            ohio          31
# 15   massachusetts          27
# 31          oregon          27
# 35       tennessee          26
# 5      connecticut          25
# 18     mississippi          24
# 41   west virginia          21
# 4         colorado          21
# 0          alabama          17
# 40      washington          14
# 10         indiana          14
# ...

# %%
graph = plt.figure(figsize=(15, 8))
plt.bar(state_nos['state'], state_nos['No of cars'], color='black', width=0.5)
plt.xlabel('State')
plt.ylabel('No of cars ')
plt.title('No of cars in each state')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# #State with maximum average price

# %%
state_max = pd.DataFrame(df.groupby('state', as_index=False, sort=True)['price'].mean())
state_max.sort_values(by=['price'], ascending=False, inplace=True)
state_max
# Out:
#              state         price
# 12        kentucky  44969.444444
# 30         ontario  30357.142857
# 25      new mexico  27375.000000
# 40      washington  26771.428571
# 9         illinois  26715.707965
# 16        michigan  23899.822485
# 0          alabama  23872.058824
# 22          nevada  23653.529412
# 32    pennsylvania  22810.210702
# 10         indiana  21391.428571
# 21        nebraska  21350.000000
# 18     mississippi  21148.333333
# 42       wisconsin  21103.191489
# 39        virginia  20041.000000
# 29        oklahoma  19839.084507
# 17       minnesota  18207.352941
# 26        new york  17850.706897
# 3       california  17836.710526
# 33    rhode island  17808.000000
# 15   massachusetts  17650.555556
# 28            ohio  17460.967742
# 34  south carolina  17270.703125
# 23   new hampshire  16757.500000
# 27  north carolina  16485.273973
# 35       tennessee  16259.576923
# 24      new jersey  16209.712644
# 19        missouri  16192.391304
# ...

# %%
graph = plt.figure(figsize=(15, 8))
plt.bar(state_max['state'], state_max['price'], color='purple', width=0.5)
plt.xlabel('State')
plt.ylabel('Average price')
plt.title('Average prices in states')
plt.xticks(rotation=70)
plt.show
# Out:
# <function matplotlib.pyplot.show>
